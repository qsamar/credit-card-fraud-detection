# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
credit_card_data=pd.read_csv('/content/credit card.csv')
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 23318  32696  1.071505  0.187075  0.895129  2.656099 -0.452814  0.179717
# 23319  32696  1.329254  0.264064 -0.048885  0.320503  0.048595 -0.678869
# 23320  32697  1.323101 -1.393103  0.433789 -1.327880 -1.717583 -0.691175
# 23321  32697  1.582101 -1.197678 -1.147417 -2.504297  0.984772  3.234035
# 23322  32697  1.398222 -1.236821  0.333811 -1.597716 -1.295506 -0.096330
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 23318 -0.247008  0.215500 -0.248462  ... -0.050902 -0.102234 -0.075050
# 23319  0.228248 -0.187475  0.008471  ... -0.560465 -1.689859  0.164856
# 23320 -1.001486 -0.132899 -1.601772  ... -0.338124 -0.900733  0.052258
# 23321 -1.492196  0.747692 -1.984488  ... -0.269321 -0.522610  0.001930
# 23322 -1.096847 -0.008739 -1.990493  ... -0.330900 -0.760100       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# 23318  0.317656  0.510180  0.034916 -0.005075  0.012346   24.56    0.0
# 23319 -0.490515  0.175748  0.029118 -0.054453  0.007967    5.00    0.0
# 23320 -0.037719  0.112664 -0.396570  0.017171  0.042853  118.75    0.0
# 23321  0.981586  0.549879 -0.190893  0.033277  0.013703   10.00    0.0
# 23322       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23323 entries, 0 to 23322
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    23323 non-null  int64
#  1   V1      23323 non-null  float64
#  2   V2      23323 non-null  float64
#  3   V3      23323 non-null  float64
#  4   V4      23323 non-null  float64
#  5   V5      23323 non-null  float64
#  6   V6      23323 non-null  float64
#  7   V7      23323 non-null  float64
#  8   V8      23323 non-null  float64
#  9   V9      23323 non-null  float64
#  10  V10     23323 non-null  float64
#  11  V11     23323 non-null  float64
#  12  V12     23323 non-null  float64
#  13  V13     23323 non-null  float64
#  14  V14     23323 non-null  float64
#  15  V15     23323 non-null  float64
#  16  V16     23323 non-null  float64
#  17  V17     23323 non-null  float64
#  18  V18     23323 non-null  float64
#  19  V19     23323 non-null  float64
#  20  V20     23323 non-null  float64
#  21  V21     23323 non-null  float64
#  22  V22     23323 non-null  float64
#  23  V23     23322 non-null  float64
#  24  V24     23322 non-null  float64
#  25  V25     23322 non-null  float64
#  26  V26     23322 non-null  float64
#  27  V27     23322 non-null  float64
#  28  V28     23322 non-null  float64
#  29  Amount  23322 non-null  float64
#  30  Class   23322 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 5.5 MB

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
print(credit_card_data['Class'].value_counts())
y=['true','fraud']
plt.pie(credit_card_data['Class'].value_counts(),labels=y)
plt.legend()
plt.show()
# Out:
# 0.0    23235
# 1.0       87
# Name: Class, dtype: int64

# %%
legit=credit_card_data[credit_card_data.Class==0]
fraud=credit_card_data[credit_card_data.Class==1]
print(legit.shape)
print(fraud.shape)
# Out:
# (23235, 31)
# (87, 31)

# %%
legit.Amount.describe()
# Out:
# count    23235.000000
# mean        73.342221
# std        212.101317
# min          0.000000
# 25%          6.000000
# 50%         17.990000
# 75%         64.990000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      87.000000
# mean       92.916437
# std       258.874172
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    17877.934108 -0.211220  0.182640   0.777441  0.228477 -0.165728
# 1.0    17765.655172 -8.687676  6.449225 -12.337122  6.273913 -6.054414
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.091411 -0.103099  0.004622  0.528952  ...  0.037214 -0.044032
# 1.0   -2.516605 -8.407369  4.393750 -2.994247  ...  0.699771  0.533789
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.137999 -0.037399  0.013631  0.125768  0.027743  0.010300  0.004198
# 1.0   -0.389656 -0.373689 -0.259653  0.349456  0.173875  0.863917  0.098963
#
#           Amount
# Class
# 0.0    73.342221
# 1.0    92.916437
#
# [2 rows x 30 columns]

# %%
legit_sample=legit.sample(n=492)

# %%
new_dataset=pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 13212  23254 -0.263073  0.124602  1.872736 -1.169198 -0.668202 -0.228090
# 5547    5650  1.165444  0.079489  0.857473  1.030213 -0.593667 -0.346776
# 13423  23743 -1.359669  0.898952  1.273269 -3.004058 -0.565684 -1.361980
# 4031    3670 -0.997411  0.308922  2.098348 -0.672282  0.927175 -1.278994
# 6847    8687  1.138664 -0.795497 -0.281918 -1.234506 -0.911956 -1.522579
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 13212 -0.271219  0.197926 -0.029676  ... -0.096099 -0.302822  0.080560
# 5547  -0.303783 -0.062729  1.598990  ... -0.169847 -0.026674 -0.069123
# 13423  0.186518  0.232991  2.073224  ...  0.008938 -0.094554 -0.065203
# 4031   0.716706 -0.300129  1.060173  ... -0.232219 -0.521714  0.183394
# 6847   0.150107 -0.521451  1.093037  ... -0.737249 -1.706349  0.004205
#
#             V24       V25       V26       V27       V28  Amount  Class
# 13212  0.071527 -0.454616 -0.552789  0.032356  0.040513   15.00    0.0
# 5547   0.541517  0.510896  0.368757 -0.045348 -0.002772    9.49    0.0
# 13423  0.458603 -0.119931 -0.584858 -0.501776  0.041305    3.91    0.0
# 4031   0.516041 -0.509787 -0.347719 -0.145652 -0.082397   13.99    0.0
# 6847   0.258210  0.415014 -0.988249 -0.010560  0.042760  160.90    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 18472  29531 -1.060676  2.608579 -2.971679  4.360089  3.738853 -2.728395
# 18773  29753  0.269614  3.549755 -5.810353  5.809370  1.538808 -2.269219
# 18809  29785  0.923764  0.344048 -2.880004  1.721680 -3.019565 -0.639736
# 20198  30852 -2.830984  0.885657  1.199930  2.861292  0.321669  0.289966
# 23308  32686  0.287953  1.728735 -1.652173  3.813544 -1.090927 -0.984745
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 18472  1.987616 -0.357345 -2.757535  ... -0.063168 -0.207385 -0.183261
# 18773 -0.824203  0.351070 -3.759059  ...  0.371121 -0.322290 -0.549856
# 18809 -3.801325  1.299096  0.864065  ...  0.899931  1.481271  0.725266
# 20198  1.767760 -2.451050  0.069736  ...  0.546589  0.334971  0.172106
# 23308 -2.202318  0.555088 -2.033892  ...  0.262202 -0.633528  0.092891
#
#             V24       V25       V26       V27       V28  Amount  Class
# 18472 -0.103679  0.896178  0.407387 -0.130918  0.192177    0.68    1.0
# 18773 -0.520629  1.378210  0.564714  0.553255  0.402400    0.68    1.0
# 18809  0.176960 -1.815638 -0.536517  0.489035 -0.049729   30.30    1.0
# 20198  0.623590 -0.527114 -0.079215 -2.532445  0.311177  104.81    1.0
# 23308  0.187613  0.368708 -0.132474  0.576561  0.309843    0.00    1.0
#
# [5 rows x 31 columns]

# %%
print(new_dataset['Class'].value_counts())
# Out:
# 0.0    492
# 1.0     87
# Name: Class, dtype: int64

# %%
plt.pie(new_dataset['Class'].value_counts())
plt.show()

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    17405.288618 -0.224391  0.112935   0.769696  0.215534 -0.166812
# 1.0    17765.655172 -8.687676  6.449225 -12.337122  6.273913 -6.054414
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.023637 -0.112139  0.067788  0.553467  ...  0.065944 -0.041995
# 1.0   -2.516605 -8.407369  4.393750 -2.994247  ...  0.699771  0.533789
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.123387 -0.010419  0.013259  0.118277  0.039653  0.016109  0.016171
# 1.0   -0.389656 -0.373689 -0.259653  0.349456  0.173875  0.863917  0.098963
#
#           Amount
# Class
# 0.0    79.840224
# 1.0    92.916437
#
# [2 rows x 30 columns]

# %%
x=new_dataset.drop(columns='Class',axis=0)
y=new_dataset['Class']
print(x)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 13212  23254 -0.263073  0.124602  1.872736 -1.169198 -0.668202 -0.228090
# 5547    5650  1.165444  0.079489  0.857473  1.030213 -0.593667 -0.346776
# 13423  23743 -1.359669  0.898952  1.273269 -3.004058 -0.565684 -1.361980
# 4031    3670 -0.997411  0.308922  2.098348 -0.672282  0.927175 -1.278994
# 6847    8687  1.138664 -0.795497 -0.281918 -1.234506 -0.911956 -1.522579
# ...      ...       ...       ...       ...       ...       ...       ...
# 18472  29531 -1.060676  2.608579 -2.971679  4.360089  3.738853 -2.728395
# 18773  29753  0.269614  3.549755 -5.810353  5.809370  1.538808 -2.269219
# 18809  29785  0.923764  0.344048 -2.880004  1.721680 -3.019565 -0.639736
# 20198  30852 -2.830984  0.885657  1.199930  2.861292  0.321669  0.289966
# 23308  32686  0.287953  1.728735 -1.652173  3.813544 -1.090927 -0.984745
#
#              V7        V8        V9  ...       V20       V21       V22  \
# 13212 -0.271219  0.197926 -0.029676  ... -0.065614 -0.096099 -0.302822
# 5547  -0.303783 -0.062729  1.598990  ... -0.144439 -0.169847 -0.026674
# 13423  0.186518  0.232991  2.073224  ... -0.475910  0.008938 -0.094554
# 4031   0.716706 -0.300129  1.060173  ... -0.098811 -0.232219 -0.521714
# 6847   0.150107 -0.521451  1.093037  ... -0.288981 -0.737249 -1.706349
# ...         ...       ...       ...  ...       ...       ...       ...
# 18472  1.987616 -0.357345 -2.757535  ... -0.089062 -0.063168 -0.207385
# 18773 -0.824203  0.351070 -3.759059  ...  0.310525  0.371121 -0.322290
# 18809 -3.801325  1.299096  0.864065  ...  0.170872  0.899931  1.481271
# 20198  1.767760 -2.451050  0.069736  ... -1.016923  0.546589  0.334971
# 23308 -2.202318  0.555088 -2.033892  ...  0.265250  0.262202 -0.633528
#
#             V23       V24       V25       V26       V27       V28  Amount
# 13212  0.080560  0.071527 -0.454616 -0.552789  0.032356  0.040513   15.00
# 5547  -0.069123  0.541517  0.510896  0.368757 -0.045348 -0.002772    9.49
# 13423 -0.065203  0.458603 -0.119931 -0.584858 -0.501776  0.041305    3.91
# 4031   0.183394  0.516041 -0.509787 -0.347719 -0.145652 -0.082397   13.99
# 6847   0.004205  0.258210  0.415014 -0.988249 -0.010560  0.042760  160.90
# ...         ...       ...       ...       ...       ...       ...     ...
# 18472 -0.183261 -0.103679  0.896178  0.407387 -0.130918  0.192177    0.68
# 18773 -0.549856 -0.520629  1.378210  0.564714  0.553255  0.402400    0.68
# 18809  0.725266  0.176960 -1.815638 -0.536517  0.489035 -0.049729   30.30
# 20198  0.172106  0.623590 -0.527114 -0.079215 -2.532445  0.311177  104.81
# 23308  0.092891  0.187613  0.368708 -0.132474  0.576561  0.309843    0.00
#
# [579 rows x 30 columns]

# %%
print("the y value is:")
print(y)
# Out:
# the y value is:
# 13212    0.0
# 5547     0.0
# 13423    0.0
# 4031     0.0
# 6847     0.0
#         ...
# 18472    1.0
# 18773    1.0
# 18809    1.0
# 20198    1.0
# 23308    1.0
# Name: Class, Length: 579, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (579, 30) (463, 30) (116, 30) (463,) (116,)

# %%
## 80 -20 test train

# %% [markdown]
# logistic regression algorithm

# %%
##logistic regression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_train_prediction=model.predict(x_train)
y_predicted=model.predict(x_test)
training_data_accuracy=accuracy_score(x_train_prediction,y_train)
print('accuracy on training data:',training_data_accuracy)
# Out:
# accuracy on training data: 0.978401727861771

# %%
x_test_prediction=model.predict(x_test)
test_data_accuracy=accuracy_score(x_test_prediction,y_test)
print('accuracy score on test_data:',test_data_accuracy)
# Out:
# accuracy score on test_data: 0.9741379310344828

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.98        99
#          1.0       0.94      0.88      0.91        17
#
#     accuracy                           0.97       116
#    macro avg       0.96      0.94      0.95       116
# weighted avg       0.97      0.97      0.97       116

# %%
plt.hist(training_data_accuracy)
plt.hist(test_data_accuracy)
plt.show()

# %%
credit_card_data.hist(figsize=(20,20))
plt.show()

# %%
corrmat=credit_card_data.corr()

# %%
fig=plt.figure(figsize=(12,9))

# %%
sns.heatmap(corrmat,vmax=.8,square=True)
plt.show()

# %%
cm=confusion_matrix(y_test,y_predicted)
print(cm)
sns.heatmap(confusion_matrix(y_test,y_predicted),annot=True)
# Out:
# [[98  1]
#  [ 2 15]]
# <Axes: >

# %% [markdown]
# naive bayes algorithm

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
# making predictions on the testing set
y_pred = gnb.predict(x_test)

# %%
# comparing actual response values (y_test) with predicted response values (y_pred)
from sklearn import metrics
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 98.27586206896551

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99        99
#          1.0       0.94      0.94      0.94        17
#
#     accuracy                           0.98       116
#    macro avg       0.97      0.97      0.97       116
# weighted avg       0.98      0.98      0.98       116

# %%
cm=confusion_matrix(y_test,y_pred)
print(cm)
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# [[98  1]
#  [ 1 16]]
# <Axes: >

# %% [markdown]
# Random forest classifier

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/credit card.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
x=df.iloc[:,:-1]
y=df["Class"]
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
modell=RandomForestClassifier()
modell.fit(X_train,y_train)
modell.score(X_train,y_train)
# Out:
# 1.0

# %%
y_predict=modell.predict(X_test)
y_predict
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[10453,     2],
#        [    7,    26]])

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     10455
#          1.0       0.93      0.79      0.85        33
#
#     accuracy                           1.00     10488
#    macro avg       0.96      0.89      0.93     10488
# weighted avg       1.00      1.00      1.00     10488

# %%
cm=confusion_matrix(y_test,y_predict)
print(cm)
sns.heatmap(confusion_matrix(y_test,y_predict),annot=True)
# Out:
# [[10453     2]
#  [    7    26]]
# <Axes: >

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
model.score(X_train,y_train)
# Out:
# 1.0

# %%
y_predict=model.predict(X_test)
y_predict
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[10451,     4],
#        [    9,    24]])

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     10455
#          1.0       0.86      0.73      0.79        33
#
#     accuracy                           1.00     10488
#    macro avg       0.93      0.86      0.89     10488
# weighted avg       1.00      1.00      1.00     10488

# %%
cm=confusion_matrix(y_test,y_predict)
print(cm)
sns.heatmap(confusion_matrix(y_test,y_predict),annot=True)
# Out:
# [[10451     4]
#  [    9    24]]
# <Axes: >

# %%
input_data = (0,-1.359807134,-0.072781173,2.536346738,1.378155224,-0.33832077,0.462387778,0.239598554,0.098697901,0.36378697,0.090794172,-0.551599533,-0.617800856,-0.991389847,-0.311169354,1.468176972,-0.470400525,0.207971242,0.02579058,0.40399296,0.251412098,-0.018306778,0.277837576,-0.11047391,0.066928075,0.128539358,-0.189114844,0.133558377,-0.021053053,149.62)
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
  print('not fraud transaction')
else:
  print('fraud transaction')
# Out:
# [0.]
# not fraud transaction
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
